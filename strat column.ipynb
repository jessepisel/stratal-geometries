# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib nbagg

# %%
tops = pd.read_csv(r"D:\prbtops_inhouse.csv")
small = tops.head()

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(tops.formation.values)
# Out:
# LabelEncoder()

# %%
tops["formation_numeric"] = le.transform(tops.formation.values)

# %%
tops.api.unique()
# Out:
# array([4902706165, 4902720708, 4902720939, ..., 4903320089, 4900522047,
#        4902523659], dtype=int64)

# %%
def stratColumn(api):
    bigColumn = []
    for well in api:
        column = []
        selected_well = tops[tops["api"] == well]
        column.insert(
            0,
            np.full(
                (np.ceil(selected_well.depth.values[0]).astype(int), 50), -1
            ),
        )
        for i in range(len(selected_well) - 1):
            thicknesses = np.ceil(np.diff(selected_well.depth)).astype(int)
            column.append(
                np.full(
                    (thicknesses[i], 50),
                    selected_well.formation_numeric.values[i],
                )
            )
        bigColumn.append(np.concatenate(column))
    plt.imshow(np.hstack(bigColumn))

# %%
stratColumn([4_902_706_165])
# Out:
# <img src="data:image/png;base64,..." width="1343">

# %%
stratColumn([4_902_523_659])

# %%
np.hstack(c)
# Out:
# array([[2, 2, 3, 3],
#        [2, 2, 3, 3],
#        [2, 2, 3, 3],
#        [2, 2, 3, 3],
#        [2, 2, 3, 3],
#        [2, 2, 3, 3],
#        [2, 2, 3, 3],
#        [2, 2, 3, 3],
#        [2, 2, 3, 3],
#        [2, 2, 3, 3]])

# %%
b
# Out:
# [array([[2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2]]), array([[2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2],
#         [2, 2]])]
